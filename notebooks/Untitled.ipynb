# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import matplotlib
from src.test_functions.many_minima import *
from src.test_functions.valley_shaped import *
from src.test_functions.plate_shaped import *
from src.test_functions.other import *

# %%
x2 = x1 = np.linspace(-10., 10., 400)
xs = np.stack(np.meshgrid(x1, x2))

# %%
ys = (Ackley().fitness_function(xs.reshape(2,-1).T)
      .reshape(xs.shape[1], xs.shape[2]))
fig = plt.figure()#figsize=(10, 10))
ax = fig.gca(projection='3d')

surf = ax.contour(x1, x2, ys, cmap=cm.coolwarm, 
                  levels=np.arange(np.min(ys).astype(np.int), 
                               np.max(ys).astype(np.int), .5))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ys = (Shwefel().fitness_function(xs.reshape(2,-1).T)
      .reshape(xs.shape[1], xs.shape[2]))
fig = plt.figure()#figsize=(10, 10))
ax = fig.gca(projection='3d')

surf = ax.contour(x1, x2, ys, cmap=cm.coolwarm, 
                  levels=np.arange(np.min(ys).astype(np.int), 
                               np.max(ys).astype(np.int), .5))
# Out:
# <img src="data:image/png;base64,..." width="640">
