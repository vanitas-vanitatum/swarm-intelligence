# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import matplotlib

# %%
def ackley_function(x, a=20, b=0.2, c=2*np.pi, axis=1):
    x = np.asarray(x)
    factor1 = np.sqrt(1. * np.square(x).sum(axis=axis) / x.shape[axis])
    factor1 = -a * np.exp(-b * factor1)

    factor2 = np.exp(1. * np.cos(c * x).sum(axis=axis) / x.shape[axis])

    return factor1 - factor2 + a + np.e

# %%
def shubert_function(x, param=418.9829, axis=1):
    x = np.asarray(x)
    sqrt_abs = np.sqrt(np.abs(x))
    sum_sin_sqrt = (x * np.sin(sqrt_abs)).sum(axis=axis)
    return param * x.shape[axis] - sum_sin_sqrt

# %%
def function(x, axis=1):
    x = np.asarray(x)
    dim = x.shape[axis]
    res = 0.

    square_x = np.square(x)
    square_x_1 = np.square(x-1)

    term1 = 100. * np.square(x[:, 1:] - square_x[:, :-1])
    return (term1 + square_x_1[:, :-1]).sum(axis=axis)

# %%
x2 = x1 = np.linspace(-5., 5., 400)

xs = np.stack(np.meshgrid(x1, x2))

# %%
ys = (function(xs.reshape(2,-1).T)
      .reshape(xs.shape[1], xs.shape[2]))
ys.shape
# Out:
# (400, 400)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.gca(projection='3d')

surf = ax.contour(x1, x2, ys, cmap=cm.coolwarm, 
                  levels=range(np.min(ys).astype(np.int), 
                               np.max(ys).astype(np.int), 1000))
# Out:
# <img src="data:image/png;base64,..." width="999.7968838230947">

# %%
np.asarray([[1,2],[3,4]]).sum(axis=1)
# Out:
# array([3, 7])
